132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 800754894 (764M) [application/zip]
# Saving to: ‘Dataset.zip’
#
# Dataset.zip         100%[===================>] 763.66M   184MB/s    in 4.3s
#
# 2021-10-27 15:22:55 (177 MB/s) - ‘Dataset.zip’ saved [800754894/800754894]

# %%
# !unzip Dataset.zip
# Out:
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# # Import Required Libraries

# %%
# !pip install pafy youtube-dl moviepy
# Out:
# Collecting pafy
#   Using cached pafy-0.5.5-py2.py3-none-any.whl (35 kB)
# Collecting youtube-dl
#   Using cached youtube_dl-2021.12.17-py2.py3-none-any.whl (1.9 MB)
# Collecting moviepy
#   Using cached moviepy-1.0.3-py3-none-any.whl
# Collecting numpy
#   Using cached numpy-1.21.6-cp37-cp37m-win_amd64.whl (14.0 MB)
# Collecting requests<3.0,>=2.8.1
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting imageio-ffmpeg>=0.2.0
#   Using cached imageio_ffmpeg-0.4.9-py3-none-win_amd64.whl (22.6 MB)
# Collecting decorator<5.0,>=4.0.2
#   Using cached decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Collecting tqdm<5.0,>=4.11.2
#   Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Collecting proglog<=1.0.0
#   Using cached proglog-0.1.10-py3-none-any.whl (6.1 kB)
# Collecting imageio<3.0,>=2.5
#   Using cached imageio-2.31.2-py3-none-any.whl (313 kB)
# Collecting pillow>=8.3.2
#   Using cached Pillow-9.5.0-cp37-cp37m-win_amd64.whl (2.5 MB)
# Requirement already satisfied: setuptools in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from imageio-ffmpeg>=0.2.0->moviepy) (65.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2022.12.7)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.3.2-cp37-cp37m-win_amd64.whl (98 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (3.4)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.0.7-py3-none-any.whl (124 kB)
# Requirement already satisfied: colorama in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from tqdm<5.0,>=4.11.2->moviepy) (0.4.6)
# Installing collected packages: youtube-dl, pafy, urllib3, tqdm, pillow, numpy, imageio-ffmpeg, decorator, charset-normalizer, requests, proglog, imageio, moviepy
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.1.1
#     Uninstalling decorator-5.1.1:
#       Successfully uninstalled decorator-5.1.1
# Successfully installed charset-normalizer-3.3.2 decorator-4.4.2 imageio-2.31.2 imageio-ffmpeg-0.4.9 moviepy-1.0.3 numpy-1.21.6 pafy-0.5.5 pillow-9.5.0 proglog-0.1.10 requests-2.31.0 tqdm-4.66.4 urllib3-2.0.7 youtube-dl-2021.12.17

# %%
# !pip install -U numpy==1.18.5
# Out:
# Collecting numpy==1.18.5
#   Using cached numpy-1.18.5-cp37-cp37m-win_amd64.whl (12.7 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
# Successfully installed numpy-1.18.5
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.2.0 requires tensorflow-estimator<2.3.0,>=2.2.0, but you have tensorflow-estimator 2.3.0 which is incompatible.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.5.3-cp37-cp37m-win_amd64.whl (7.2 MB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.38.0-py3-none-any.whl (965 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from matplotlib) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from matplotlib) (2.8.2)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.5-cp37-cp37m-win_amd64.whl (55 kB)
# Collecting pyparsing>=2.2.1
#   Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: typing-extensions in c:\users\phi\appdata\roaming\python\python37\site-packages (from kiwisolver>=1.0.1->matplotlib) (3.7.4.3)
# Requirement already satisfied: six>=1.5 in c:\users\phi\appdata\roaming\python\python37\site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.38.0 kiwisolver-1.4.5 matplotlib-3.5.3 pyparsing-3.1.2

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from opencv-python) (1.21.6)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.9.0.80

# %%
# !pip install tensorflow==2.3.0
# Out:
# Collecting tensorflow==2.3.0
#   Using cached tensorflow-2.3.0-cp37-cp37m-win_amd64.whl (342.5 MB)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from tensorflow==2.3.0) (1.16.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\phi\appdata\roaming\python\python37\site-packages (from tensorflow==2.3.0) (1.15.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from tensorflow==2.3.0) (3.3.0)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from tensorflow==2.3.0) (2.10.0)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from tensorflow==2.3.0) (2.1.0)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from tensorflow==2.3.0) (1.6.3)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from tensorflow==2.3.0) (2.3.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from tensorflow==2.3.0) (0.38.4)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from tensorflow==2.3.0) (2.3.0)
# Requirement already satisfied: scipy==1.4.1 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from tensorflow==2.3.0) (1.4.1)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from tensorflow==2.3.0) (1.18.5)
# Requirement already satisfied: google-pasta>=0.1.8 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from tensorflow==2.3.0) (0.2.0)
# Collecting tensorboard<3,>=2.3.0
#   Using cached tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from tensorflow==2.3.0) (3.20.0)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from tensorflow==2.3.0) (1.62.2)
# Requirement already satisfied: gast==0.3.3 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from tensorflow==2.3.0) (0.3.3)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from tensorflow==2.3.0) (1.1.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.31.0)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.2.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.35.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (65.6.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.4.4)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.11.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2022.12.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from werkzeug>=1.0.1->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.11.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\phi\appdata\roaming\python\python37\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.7.4.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.2.2)
# Installing collected packages: tensorboard-data-server, tensorboard, tensorflow
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.2.2
#     Uninstalling tensorboard-2.2.2:
#       Successfully uninstalled tensorboard-2.2.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.2.0
#     Uninstalling tensorflow-2.2.0:
#       Successfully uninstalled tensorflow-2.2.0
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\users\\phi\\anaconda3\\envs\\notebook1\\lib\\site-packages\\~ensorflow\\lite\\experimental\\microfrontend\\python\\ops\\_audio_microfrontend_op.so'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)

# %%
# !pip install protobuf==3.20
# !pip install tensorflow-estimator==2.3.0
# Out:
# Collecting protobuf==3.20
#   Downloading protobuf-3.20.0-cp37-cp37m-win_amd64.whl (905 kB)
#      -------------------------------------- 905.1/905.1 kB 5.7 MB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# Successfully installed protobuf-3.20.0
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.2.0 requires tensorflow-estimator<2.3.0,>=2.2.0, but you have tensorflow-estimator 2.3.0 which is incompatible.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)

# %%
# !pip install scikit-learn==1.0.2 scipy==1.4.1 matplotlib==3.5.3 numpy==1.18.5
# Out:
# Requirement already satisfied: scikit-learn==1.0.2 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (1.0.2)
# Requirement already satisfied: scipy==1.4.1 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (1.4.1)
# Requirement already satisfied: matplotlib==3.5.3 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (3.5.3)
# Collecting numpy==1.18.5
#   Using cached numpy-1.18.5-cp37-cp37m-win_amd64.whl (12.7 MB)
# Requirement already satisfied: joblib>=0.11 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from scikit-learn==1.0.2) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from scikit-learn==1.0.2) (3.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from matplotlib==3.5.3) (22.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from matplotlib==3.5.3) (3.1.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from matplotlib==3.5.3) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from matplotlib==3.5.3) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from matplotlib==3.5.3) (9.5.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from matplotlib==3.5.3) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from matplotlib==3.5.3) (0.11.0)
# Requirement already satisfied: typing-extensions in c:\users\phi\appdata\roaming\python\python37\site-packages (from kiwisolver>=1.0.1->matplotlib==3.5.3) (3.7.4.3)
# Requirement already satisfied: six>=1.5 in c:\users\phi\appdata\roaming\python\python37\site-packages (from python-dateutil>=2.7->matplotlib==3.5.3) (1.15.0)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\users\\phi\\anaconda3\\envs\\notebook1\\lib\\site-packages\\~umpy\\.libs\\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)

# %%
# !pip install tensorflow-estimator==2.3.0 keras==2.4.3 keras-applications==1.0.8 keras-preprocessing==1.1.2
# Out:
# Requirement already satisfied: tensorflow-estimator==2.3.0 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (2.3.0)
# Collecting keras==2.4.3
#   Using cached Keras-2.4.3-py2.py3-none-any.whl (36 kB)
# Collecting keras-applications==1.0.8
#   Using cached Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
# Requirement already satisfied: keras-preprocessing==1.1.2 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (1.1.2)
# Requirement already satisfied: scipy>=0.14 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from keras==2.4.3) (1.4.1)
# Requirement already satisfied: h5py in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from keras==2.4.3) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from keras==2.4.3) (1.18.5)
# Collecting pyyaml
#   Downloading PyYAML-6.0.1-cp37-cp37m-win_amd64.whl (153 kB)
#      -------------------------------------- 153.2/153.2 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.9.0 in c:\users\phi\appdata\roaming\python\python37\site-packages (from keras-preprocessing==1.1.2) (1.15.0)
# Installing collected packages: pyyaml, keras-applications, keras
# Successfully installed keras-2.4.3 keras-applications-1.0.8 pyyaml-6.0.1
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)

# %%
# %env PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python
# Out:
# env: PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- -------------------
# absl-py                      2.1.0
# anyio                        3.5.0
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# astunparse                   1.6.3
# attrs                        22.1.0
# backcall                     0.2.0
# beautifulsoup4               4.11.1
# bleach                       4.1.0
# cachetools                   4.2.4
# certifi                      2024.2.2
# cffi                         1.15.1
# charset-normalizer           3.3.2
# colorama                     0.4.6
# cycler                       0.11.0
# debugpy                      1.5.1
# decorator                    4.4.2
# defusedxml                   0.7.1
# entrypoints                  0.4
# fastjsonschema               2.16.2
# flatbuffers                  1.12
# flit_core                    3.6.0
# fonttools                    4.38.0
# future                       1.0.0
# gast                         0.3.3
# google-auth                  1.35.0
# google-auth-oauthlib         0.4.6
# google-pasta                 0.2.0
# graphviz                     0.20.3
# grpcio                       1.62.2
# h5py                         2.10.0
# idna                         3.4
# imageio                      2.31.2
# imageio-ffmpeg               0.4.9
# importlib-metadata           4.11.3
# importlib-resources          5.2.0
# ipykernel                    6.15.2
# ipython                      7.31.1
# ipython-genutils             0.2.0
# jedi                         0.18.1
# Jinja2                       3.1.2
# joblib                       1.3.2
# jsonschema                   4.17.3
# jupyter_client               7.4.9
# jupyter_core                 4.11.2
# jupyter-server               1.23.4
# jupyterlab-pygments          0.1.2
# Keras                        2.4.3
# Keras-Applications           1.0.8
# Keras-Preprocessing          1.1.2
# keras-tuner                  1.0.2
# kiwisolver                   1.4.5
# libclang                     18.1.1
# lxml                         4.9.1
# Markdown                     3.4.4
# MarkupSafe                   2.1.1
# matplotlib                   3.5.3
# matplotlib-inline            0.1.6
# mistune                      0.8.4
# moviepy                      1.0.3
# nbclassic                    0.5.2
# nbclient                     0.5.13
# nbconvert                    6.5.4
# nbformat                     5.7.0
# nest-asyncio                 1.5.6
# notebook                     6.5.2
# notebook_shim                0.2.2
# numpy                        1.18.5
# oauthlib                     3.2.2
# opencv-python                4.9.0.80
# opt-einsum                   3.3.0
# packaging                    22.0
# pafy                         0.5.5
# pandas                       1.3.5
# pandocfilters                1.5.0
# parso                        0.8.3
# pickleshare                  0.7.5
# Pillow                       9.5.0
# pip                          22.3.1
# pkgutil_resolve_name         1.3.10
# proglog                      0.1.10
# prometheus-client            0.14.1
# prompt-toolkit               3.0.36
# protobuf                     3.20.0
# psutil                       5.9.0
# pyasn1                       0.5.1
# pyasn1-modules               0.3.0
# pycparser                    2.21
# pydot                        2.0.0
# pydotplus                    2.0.2
# Pygments                     2.11.2
# pyparsing                    3.1.2
# pyrsistent                   0.18.0
# python-dateutil              2.8.2
# pytz                         2024.1
# pywin32                      305.1
# pywinpty                     2.0.10
# PyYAML                       6.0.1
# pyzmq                        23.2.0
# requests                     2.31.0
# requests-oauthlib            2.0.0
# rsa                          4.9
# scikit-learn                 1.0.2
# scipy                        1.4.1
# Send2Trash                   1.8.0
# setuptools                   65.6.3
# six                          1.15.0
# sniffio                      1.2.0
# soupsieve                    2.3.2.post1
# tabulate                     0.9.0
# tensorboard                  2.11.2
# tensorboard-data-server      0.6.1
# tensorboard-plugin-wit       1.8.1
# tensorflow                   2.3.0
# tensorflow-estimator         2.3.0
# tensorflow-io-gcs-filesystem 0.31.0
# termcolor                    2.3.0
# terminado                    0.17.1
# terminaltables               3.1.10
# tf-estimator-nightly         2.8.0.dev2021122109
# threadpoolctl                3.1.0
# tinycss2                     1.2.1
# tornado                      6.2
# tqdm                         4.66.4
# traitlets                    5.7.1
# typing-extensions            3.7.4.3
# urllib3                      1.26.14
# wcwidth                      0.2.5
# webencodings                 0.5.1
# websocket-client             0.58.0
# Werkzeug                     2.2.3
# wheel                        0.38.4
# wincertstore                 0.2
# wrapt                        1.16.0
# youtube-dl                   2021.12.17
# zipp                         3.11.0
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)

# %%
import os
import cv2
import pafy
import math
import random
import datetime as dt
import tensorflow as tf
from collections import deque
import matplotlib.pyplot as plt

#from moviepy.editor import *
# %matplotlib inline

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
# from tensorflow.keras.utils import plot_model

# %% [markdown]
# # Select Randomness

# %%
import numpy as np
seed_constant = 5
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)

# %% [markdown]
# # View the dataset

# %%
# Create a Matplotlib figure and specify the size of the figure.
plt.figure(figsize = (20, 20))
 
# Get the names of all classes/categories in UCF50.
all_classes_names = os.listdir('Dataset')
 
# Generate a list of 20 random values. The values will be between 0-50, 
# where 50 is the total number of class in the dataset. 
# random_range = random.sample(range(len(all_classes_names)), len(all_classes_names))
 
# Iterating through all the generated random values.
for counter, random_index in enumerate(range(len(all_classes_names)), 1):
 
    # Retrieve a Class Name using the Random Index.
    selected_class_Name = all_classes_names[random_index]
 
    # Retrieve the list of all the video files present in the randomly selected Class Directory.
    video_files_names_list = os.listdir(f'Dataset/{selected_class_Name}')
 
    # Randomly select a video file from the list retrieved from the randomly selected Class Directory.
    selected_video_file_name = random.choice(video_files_names_list)
 
    # Initialize a VideoCapture object to read from the video File.
    video_reader = cv2.VideoCapture(f'Dataset/{selected_class_Name}/{selected_video_file_name}')
    video_reader.set(1, 25)

    # Read the first frame of the video file.
    _, bgr_frame = video_reader.read()
  
    bgr_frame = cv2.resize(bgr_frame ,(224,224))
    # Release the VideoCapture object. 
    video_reader.release()
 
    # Convert the frame from BGR into RGB format. 
    rgb_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2RGB)
 
    # Write the class name on the video frame.
    cv2.putText(rgb_frame, selected_class_Name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 200, 255), 2)
    
    # Display the frame.
    plt.subplot(5, 4, counter);plt.imshow(rgb_frame);plt.axis('off')

# %% [markdown]
# # Set Dataset Variables

# %%
# Specify the height and width to which each video frame will be resized in our dataset.
IMAGE_HEIGHT , IMAGE_WIDTH = 64, 64
 
# Specify the number of frames of a video that will be fed to the model as one sequence.
SEQUENCE_LENGTH = 30
 
# Specify the directory containing the UCF50 dataset. 
DATASET_DIR = "Dataset"
 
# Specify the list containing the names of the classes used for training. Feel free to choose any set of classes.
CLASSES_LIST = ["handclapping", "jogging", "stealing", "lifting"]

# %% [markdown]
# # Data pre-processing

# %%
def frames_extraction(video_path):
    '''
    This function will extract the required frames from a video after resizing and normalizing them.
    Args:
        video_path: The path of the video in the disk, whose frames are to be extracted.
    Returns:
        frames_list: A list containing the resized and normalized frames of the video.
    '''

    # Declare a list to store video frames.
    frames_list = []
    
    # Read the Video File using the VideoCapture object.
    video_reader = cv2.VideoCapture(video_path)

    # Get the total number of frames in the video.
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the the interval after which frames will be added to the list.
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)

    # Iterate through the Video Frames.
    for frame_counter in range(SEQUENCE_LENGTH):

        # Set the current frame position of the video.
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)

        # Reading the frame from the video. 
        success, frame = video_reader.read() 

        # Check if Video frame is not successfully read then break the loop
        if not success:
            break

        # Resize the Frame to fixed height and width.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))
        
        # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1
        normalized_frame = resized_frame / 255
        
        # Append the normalized frame into the frames list
        frames_list.append(normalized_frame)
    
    # Release the VideoCapture object. 
    video_reader.release()

    # Return the frames list.
    return frames_list

# %%
def create_dataset():
    '''
    This function will extract the data of the selected classes and create the required dataset.
    Returns:
        features:          A list containing the extracted frames of the videos.
        labels:            A list containing the indexes of the classes associated with the videos.
        video_files_paths: A list containing the paths of the videos in the disk.
    '''

    # Declared Empty Lists to store the features, labels and video file path values.
    features = []
    labels = []
    video_files_paths = []
    
    # Iterating through all the classes mentioned in the classes list
    for class_index, class_name in enumerate(CLASSES_LIST):
        
        # Display the name of the class whose data is being extracted.
        print(f'Extracting Data of Class: {class_name}')
        
        # Get the list of video files present in the specific class name directory.
        files_list = os.listdir(os.path.join(DATASET_DIR, class_name))
        
        # Iterate through all the files present in the files list.
        for file_name in files_list:
            
            # Get the complete video path.
            video_file_path = os.path.join(DATASET_DIR, class_name, file_name)

            # Extract the frames of the video file.
            frames = frames_extraction(video_file_path)

            # Check if the extracted frames are equal to the SEQUENCE_LENGTH specified above.
            # So ignore the vides having frames less than the SEQUENCE_LENGTH.
            if len(frames) == SEQUENCE_LENGTH:

                # Append the data to their repective lists.
                features.append(frames)
                labels.append(class_index)
                video_files_paths.append(video_file_path)

    # Converting the list to numpy arrays
    features = np.asarray(features)
    labels = np.array(labels)  
    
    # Return the frames, class index, and video file path.
    return features, labels, video_files_paths

# %%
# Create the dataset.
features, labels, video_files_paths = create_dataset()
# Out:
# Extracting Data of Class: handclapping
# Extracting Data of Class: jogging
# Extracting Data of Class: stealing
# Extracting Data of Class: lifting

# %%
# Using Keras's to_categorical method to convert labels into one-hot-encoded vectors
one_hot_encoded_labels = to_categorical(labels)

# %%
# Split the Data into Train ( 75% ) and Test Set ( 25% ).
features_train, features_test, labels_train, labels_test = train_test_split(features, one_hot_encoded_labels, test_size = 0.25, shuffle = True, random_state = seed_constant)
features = None
labels = None

# %% [markdown]
# # Model Creation LRCN (Long-term Recurrent Convolutional Network)

# %%
from keras.models import Sequential
from keras.layers import TimeDistributed, Conv2D, MaxPooling2D, Flatten, LSTM, Dense, Dropout
from keras.regularizers import l2
from keras.applications import VGG16

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, TimeDistributed, Conv2D, MaxPooling2D, Flatten
from keras.regularizers import l2
from keras.optimizers import Adam

def create_LRCN_model():
    '''
    This function will construct the required LRCN model.
    Returns:
        model: It is the required constructed LRCN model.
    '''

    # We will use a Sequential model for model construction.
    model = Sequential()
    
    # Define the Model Architecture.
    ########################################################################################################################
    
    model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.01)), input_shape=(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((4, 4))))
    model.add(TimeDistributed(Dropout(0.25)))  # Thêm lớp Dropout với tỷ lệ dropout là 0.25
    
    model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.01))))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((4, 4))))
    model.add(TimeDistributed(Dropout(0.25)))  # Thêm lớp Dropout với tỷ lệ dropout là 0.25
    
    model.add(TimeDistributed(Conv2D(128, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.01))))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(TimeDistributed(Dropout(0.25)))  # Thêm lớp Dropout với tỷ lệ dropout là 0.25
    
    model.add(TimeDistributed(Conv2D(256, (2, 2), padding='same', activation='relu', kernel_regularizer=l2(0.01))))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(TimeDistributed(Dropout(0.25)))  # Thêm lớp Dropout với tỷ lệ dropout là 0.25
                                      
    model.add(TimeDistributed(Flatten()))
    
    # Thêm lớp LSTM
    model.add(LSTM(32, return_sequences=True))  # Thêm return_sequences=True để truyền output của LSTM tới lớp tiếp theo
    model.add(Dropout(0.5))  # Thêm lớp Dropout với tỷ lệ dropout là 0.5
    
    model.add(LSTM(32))  # Lớp LSTM thứ hai, này không cần return_sequences=True vì chúng ta chỉ cần output cuối cùng
    model.add(Dropout(0.5))  # Thêm lớp Dropout với tỷ lệ dropout là 0.5
    
    model.add(Dense(len(CLASSES_LIST), activation='softmax'))

    ########################################################################################################################

    # Display the model summary.
    model.summary()
    
    # Trình tối ưu hóa
    optimizer = Adam(learning_rate=0.0001)
    
    # Compile the model
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
    # Return the constructed LRCN model.
    return model

# %%
model = create_LRCN_model()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_34 (TimeDis (None, 30, 64, 64, 32)    896
# _________________________________________________________________
# time_distributed_35 (TimeDis (None, 30, 64, 64, 32)    128
# _________________________________________________________________
# time_distributed_36 (TimeDis (None, 30, 16, 16, 32)    0
# _________________________________________________________________
# time_distributed_37 (TimeDis (None, 30, 16, 16, 32)    0
# _________________________________________________________________
# time_distributed_38 (TimeDis (None, 30, 16, 16, 64)    18496
# _________________________________________________________________
# time_distributed_39 (TimeDis (None, 30, 16, 16, 64)    256
# _________________________________________________________________
# time_distributed_40 (TimeDis (None, 30, 4, 4, 64)      0
# _________________________________________________________________
# time_distributed_41 (TimeDis (None, 30, 4, 4, 64)      0
# _________________________________________________________________
# time_distributed_42 (TimeDis (None, 30, 4, 4, 128)     73856
# _________________________________________________________________
# time_distributed_43 (TimeDis (None, 30, 4, 4, 128)     512
# _________________________________________________________________
# time_distributed_44 (TimeDis (None, 30, 2, 2, 128)     0
# _________________________________________________________________
# time_distributed_45 (TimeDis (None, 30, 2, 2, 128)     0
# _________________________________________________________________
# time_distributed_46 (TimeDis (None, 30, 2, 2, 256)     131328
# _________________________________________________________________
# time_distributed_47 (TimeDis (None, 30, 2, 2, 256)     1024
# _________________________________________________________________
# time_distributed_48 (TimeDis (None, 30, 1, 1, 256)     0
# _________________________________________________________________
# time_distributed_49 (TimeDis (None, 30, 1, 1, 256)     0
# _________________________________________________________________
# time_distributed_50 (TimeDis (None, 30, 256)           0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 30, 32)            36992
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 30, 32)            0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 271,940
# Trainable params: 270,980
# Non-trainable params: 960
# _________________________________________________________________

# %%
# !pip install pydot==2.0.0
# !pip install pydotplus==2.0.2
# !pip install graphviz
# Out:
# Requirement already satisfied: pydot==2.0.0 in c:\users\phi\anaconda3\envs\notebook1_20240519\lib\site-packages (2.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\phi\anaconda3\envs\notebook1_20240519\lib\site-packages (from pydot==2.0.0) (3.1.2)
# Requirement already satisfied: pydotplus==2.0.2 in c:\users\phi\anaconda3\envs\notebook1_20240519\lib\site-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in c:\users\phi\anaconda3\envs\notebook1_20240519\lib\site-packages (from pydotplus==2.0.2) (3.1.2)
# Requirement already satisfied: graphviz in c:\users\phi\anaconda3\envs\notebook1_20240519\lib\site-packages (0.20.1)

# %%
# !pip install graphviz
# !pip install pydot
# !pip install pydotplus
# Out:
# Requirement already satisfied: graphviz in c:\users\phi\anaconda3\envs\notebook1_20240519\lib\site-packages (0.20.1)
# Requirement already satisfied: pydot in c:\users\phi\anaconda3\envs\notebook1_20240519\lib\site-packages (2.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\phi\anaconda3\envs\notebook1_20240519\lib\site-packages (from pydot) (3.1.2)
# Requirement already satisfied: pydotplus in c:\users\phi\anaconda3\envs\notebook1_20240519\lib\site-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in c:\users\phi\anaconda3\envs\notebook1_20240519\lib\site-packages (from pydotplus) (3.1.2)

# %%
# !pip install python-graphviz==0.20.1
# Out:
# ERROR: Could not find a version that satisfies the requirement python-graphviz==0.20.1 (from versions: none)
# ERROR: No matching distribution found for python-graphviz==0.20.1

# %%
import pydot
import pydotplus
from pydotplus import graphviz
# from keras.utils.vis_utils import plot_model
# from keras.utils.vis_utils import model_to_dot
# keras.utils.vis_utils.pydot = pydot

from tensorflow.python.keras.utils.vis_utils import plot_model

plot_model(model, to_file = 'Suspicious_Human_Activity_LRCN_Model_202405212328.png', show_shapes = True, show_layer_names = True)

# %% [markdown]
# # Model Training

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
class CustomEarlyStopping(tf.keras.callbacks.Callback):
    def __init__(self, monitor1='val_loss', monitor2='accuracy', patience=10, verbose=0, restore_best_weights=False):
        super(CustomEarlyStopping, self).__init__()
        self.monitor1 = monitor1
        self.monitor2 = monitor2
        self.patience = patience
        self.verbose = verbose
        self.restore_best_weights = restore_best_weights
        self.wait = 0
        self.stopped_epoch = 0
        self.best_weights = None
        self.best_score1 = np.Inf
        self.best_score2 = -np.Inf

    def on_train_begin(self, logs=None):
        self.wait = 0
        self.stopped_epoch = 0
        self.best_score1 = np.Inf
        self.best_score2 = -np.Inf
        if self.restore_best_weights:
            self.best_weights = self.model.get_weights()

    def on_epoch_end(self, epoch, logs=None):
        current_score1 = logs.get(self.monitor1)
        current_score2 = logs.get(self.monitor2)

        if current_score1 is None or current_score2 is None:
            return

        if current_score1 < self.best_score1 or current_score2 > self.best_score2:
            self.best_score1 = min(current_score1, self.best_score1)
            self.best_score2 = max(current_score2, self.best_score2)
            if self.restore_best_weights:
                self.best_weights = self.model.get_weights()
            self.wait = 0
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.stopped_epoch = epoch
                self.model.stop_training = True
                if self.restore_best_weights:
                    if self.verbose > 0:
                        print('Restoring model weights from the end of the best epoch.')
                    self.model.set_weights(self.best_weights)

    def on_train_end(self, logs=None):
        if self.stopped_epoch > 0 and self.verbose > 0:
            print(f'\nEpoch {self.stopped_epoch + 1}: early stopping')

# %%
from keras.callbacks import LearningRateScheduler

def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

lr_scheduler = LearningRateScheduler(scheduler)

# %%
import numpy as np
from tensorflow.keras.utils import Sequence

class CustomDataGenerator(Sequence):
    def __init__(self, x_set, y_set, batch_size, datagen, is_training=True):
        self.x, self.y = x_set, y_set
        self.batch_size = batch_size
        self.datagen = datagen
        self.indexes = np.arange(len(self.x))
        self.is_training = is_training
    
    def __len__(self):
        return int(np.ceil(len(self.x) / self.batch_size))
    
    def __getitem__(self, idx):
        batch_indexes = self.indexes[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_x = self.x[batch_indexes]
        batch_y = self.y[batch_indexes]

        if self.is_training:
            # Data augmentation for each frame in the sequence during training
            augmented_batch_x = np.zeros_like(batch_x)
            for i in range(batch_x.shape[0]):
                for j in range(batch_x.shape[1]):
                    augmented_batch_x[i, j] = self.datagen.random_transform(batch_x[i, j])
            return augmented_batch_x, batch_y
        else:
            # No data augmentation during validation
            return batch_x, batch_y
    
    def on_epoch_end(self):
        if self.is_training:
            np.random.shuffle(self.indexes)


from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# %%
from tensorflow.keras.optimizers import SGD, RMSprop, Adam

# %%
from tensorflow.keras.optimizers import Adam
# Create an Instance of Early Stopping Callback.
early_stopping_callback = EarlyStopping(monitor = 'accuracy', patience = 15, mode = 'max', restore_best_weights = True)
# early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 10, restore_best_weights = True)
#early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
custom_early_stopping = CustomEarlyStopping(monitor1='val_loss', monitor2='accuracy', patience=10, restore_best_weights=True)
# reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001)
# model_checkpoint = ModelCheckpoint('best_model_20240520.h5', monitor='val_loss', save_best_only=True)
# Compile the model and specify loss function, optimizer and metrics to the model.
optimizer = Adam(learning_rate=0.0001)
#optimizer_sgd = SGD(learning_rate=0.001, momentum=0.9)
model.compile(loss = 'categorical_crossentropy', optimizer = optimizer, metrics = ["accuracy"])
 
# Start training the model.
model_training_history = model.fit(x = features_train, y = labels_train, epochs = 100, batch_size = 4 , shuffle = True, validation_data=(features_test, labels_test), callbacks = [early_stopping_callback])
# Out:
# Epoch 1/100
# 66/66 [==============================] - 22s 340ms/step - loss: 4.2863 - accuracy: 0.4138 - val_loss: 4.4714 - val_accuracy: 0.2841
# Epoch 2/100
# 66/66 [==============================] - 23s 348ms/step - loss: 4.0559 - accuracy: 0.6015 - val_loss: 4.5330 - val_accuracy: 0.2841
# Epoch 3/100
# 66/66 [==============================] - 23s 355ms/step - loss: 3.9588 - accuracy: 0.5594 - val_loss: 4.5418 - val_accuracy: 0.2841
# Epoch 4/100
# 66/66 [==============================] - 23s 350ms/step - loss: 3.8081 - accuracy: 0.6284 - val_loss: 4.6217 - val_accuracy: 0.2841
# Epoch 5/100
# 66/66 [==============================] - 24s 358ms/step - loss: 3.7181 - accuracy: 0.6628 - val_loss: 4.7074 - val_accuracy: 0.2841
# Epoch 6/100
# 66/66 [==============================] - 24s 357ms/step - loss: 3.5034 - accuracy: 0.7510 - val_loss: 4.6977 - val_accuracy: 0.2841
# Epoch 7/100
# 66/66 [==============================] - 23s 352ms/step - loss: 3.4261 - accuracy: 0.7625 - val_loss: 4.5413 - val_accuracy: 0.2841
# Epoch 65/100
# 66/66 [==============================] - 25s 384ms/step - loss: 1.4823 - accuracy: 0.9464 - val_loss: 1.7542 - val_accuracy: 0.8409
# Epoch 66/100
# 66/66 [==============================] - 25s 376ms/step - loss: 1.4553 - accuracy: 0.9464 - val_loss: 1.8013 - val_accuracy: 0.8068
# Epoch 67/100
# 66/66 [==============================] - 25s 372ms/step - loss: 1.4664 - accuracy: 0.9464 - val_loss: 1.8691 - val_accuracy: 0.7500
# Epoch 68/100
# 66/66 [==============================] - 24s 367ms/step - loss: 1.4599 - accuracy: 0.9464 - val_loss: 1.8903 - val_accuracy: 0.7727
# Epoch 69/100
# 66/66 [==============================] - 24s 371ms/step - loss: 1.3768 - accuracy: 0.9732 - val_loss: 1.7433 - val_accuracy: 0.8182
# Epoch 70/100
# 66/66 [==============================] - 25s 382ms/step - loss: 1.4121 - accuracy: 0.9540 - val_loss: 1.7379 - val_accuracy: 0.8182
# Epoch 71/100
# 66/66 [==============================] - 25s 372ms/step - loss: 1.3597 - accuracy: 0.9693 - val_loss: 1.7092 - val_accuracy: 0.8409

# %%
# !pip install keras-tuner==1.0.2
# Out:
# Collecting keras-tuner==1.0.2
#   Downloading keras-tuner-1.0.2.tar.gz (62 kB)
#      -------------------------------------- 63.0/63.0 kB 421.8 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: packaging in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from keras-tuner==1.0.2) (22.0)
# Collecting future
#   Downloading future-1.0.0-py3-none-any.whl (491 kB)
#      -------------------------------------- 491.3/491.3 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from keras-tuner==1.0.2) (1.18.5)
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting terminaltables
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: colorama in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from keras-tuner==1.0.2) (0.4.6)
# Requirement already satisfied: tqdm in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from keras-tuner==1.0.2) (4.66.4)
# Requirement already satisfied: requests in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from keras-tuner==1.0.2) (2.31.0)
# Requirement already satisfied: scipy in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from keras-tuner==1.0.2) (1.4.1)
# Requirement already satisfied: scikit-learn in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from keras-tuner==1.0.2) (1.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from requests->keras-tuner==1.0.2) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from requests->keras-tuner==1.0.2) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from requests->keras-tuner==1.0.2) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from requests->keras-tuner==1.0.2) (2024.2.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from scikit-learn->keras-tuner==1.0.2) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\phi\anaconda3\envs\notebook1\lib\site-packages (from scikit-learn->keras-tuner==1.0.2) (3.1.0)
# Building wheels for collected packages: keras-tuner
#   Building wheel for keras-tuner (setup.py): started
#   Building wheel for keras-tuner (setup.py): finished with status 'done'
#   Created wheel for keras-tuner: filename=keras_tuner-1.0.2-py3-none-any.whl size=78930 sha256=63394902607d8b594677658c2261a3f86a98aca39e794c373ea89e40ce16aa6b
#   Stored in directory: c:\users\phi\appdata\local\pip\cache\wheels\aa\7c\76\56c12f123a2fb23d23fa5bd8cd8e1179e7b5923c4b4a14508d
# Successfully built keras-tuner
# Installing collected packages: terminaltables, tabulate, future, keras-tuner
# Successfully installed future-1.0.0 keras-tuner-1.0.2 tabulate-0.9.0 terminaltables-3.1.10
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\phi\anaconda3\envs\notebook1\lib\site-packages)

# %%
from kerastuner import HyperModel
from keras.models import Sequential
from keras.layers import TimeDistributed, Conv2D, MaxPooling2D, Flatten, LSTM, Dense, Dropout, BatchNormalization
from keras.regularizers import l2
from keras.optimizers import Adam

class LRCNHyperModel(HyperModel):
    def __init__(self, sequence_length, image_height, image_width, classes_list):
        self.sequence_length = sequence_length
        self.image_height = image_height
        self.image_width = image_width
        self.classes_list = classes_list

    def build(self, hp):
        model = Sequential()
        
        model.add(TimeDistributed(Conv2D(
            filters=hp.Int('conv1_filters', min_value=32, max_value=128, step=32),
            kernel_size=hp.Choice('conv1_kernel', values=[3, 5]),
            activation='relu',
            kernel_regularizer=l2(0.01)
        ), input_shape=(self.sequence_length, self.image_height, self.image_width, 3)))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D(pool_size=(4, 4))))
        model.add(TimeDistributed(Dropout(hp.Float('dropout1', min_value=0.2, max_value=0.5, step=0.1))))

        model.add(TimeDistributed(Conv2D(
            filters=hp.Int('conv2_filters', min_value=64, max_value=256, step=64),
            kernel_size=hp.Choice('conv2_kernel', values=[3, 5]),
            activation='relu',
            kernel_regularizer=l2(0.01)
        )))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D(pool_size=(4, 4))))
        model.add(TimeDistributed(Dropout(hp.Float('dropout2', min_value=0.2, max_value=0.5, step=0.1))))

        model.add(TimeDistributed(Flatten()))

        model.add(LSTM(
            units=hp.Int('lstm_units', min_value=32, max_value=128, step=32),
            return_sequences=False
        ))
        model.add(Dropout(hp.Float('dropout3', min_value=0.2, max_value=0.5, step=0.1)))

        model.add(Dense(len(self.classes_list), activation='softmax', kernel_regularizer=l2(0.01)))

        model.compile(
            optimizer=Adam(hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='LOG')),
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )

        return model

# Example usage

hypermodel = LRCNHyperModel(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, CLASSES_LIST)

# %%
from kerastuner.tuners import RandomSearch

tuner = RandomSearch(
    hypermodel,
    objective='val_accuracy',
    max_trials=20,  # Số lần thử nghiệm
    executions_per_trial=1,
    directory='my_dir',
    project_name='lrcn_tuning'
)

# Assuming X_train, y_train, X_val, y_val are already defined and preprocessed

# Callback for early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Search for the best hyperparameters
tuner.search(features_train, labels_train, 
             validation_split = 0.25,
             epochs=50, 
             callbacks=[early_stopping], 
             batch_size=32)

# Get the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Build the model with the best hyperparameters
model = hypermodel.build(best_hps)

# Train the model with the best hyperparameters
history = model.fit(features_train, labels_train, 
                    validation_split = 0.25, 
                    epochs=100, 
                    callbacks=[early_stopping], 
                    batch_size=32)
# Out:
# INFO:tensorflow:Reloading Oracle from existing project my_dir\lrcn_tuning\oracle.json
#
# Search: Running Trial #1
#
# Hyperparameter    |Value             |Best Value So Far
# conv1_filters     |96                |?
# conv1_kernel      |5                 |?
# dropout1          |0.5               |?
# conv2_filters     |256               |?
# conv2_kernel      |3                 |?
# dropout2          |0.4               |?
# lstm_units        |96                |?
# dropout3          |0.3               |?
# learning_rate     |0.00072494        |?
#
# Epoch 1/50
# 8/8 [==============================] - ETA: 0s - loss: 2.9737 - accuracy: 0.3413
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19884\2491898383.py in <module>
#      20              epochs=50,
#      21              callbacks=[early_stopping],
# ---> 22              batch_size=32)
#      23
#      24 # Get the best hyperparameters
#
# ~\anaconda3\envs\notebook1\lib\site-packages\kerastuner\engine\base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     129
#     130             self.on_trial_begin(trial)
# --> 131             self.run_trial(trial, *fit_args, **fit_kwargs)
#     132             self.on_trial_end(trial)
#     133         self.on_search_end()
#
# ~\anaconda3\envs\notebook1\lib\site-packages\kerastuner\engine\multi_execution_tuner.py in run_trial(self, trial, *fit_args, **fit_kwargs)
#      94             copied_fit_kwargs['callbacks'] = callbacks
#      95
# ---> 96             history = self._build_and_fit_model(trial, fit_args, copied_fit_kwargs)
#      97             for metric, epoch_values in history.history.items():
#      98                 if self.oracle.objective.direction == 'min':
#
# ~\anaconda3\envs\notebook1\lib\site-packages\kerastuner\engine\tuner.py in _build_and_fit_model(self, trial, fit_args, fit_kwargs)
#     139         """
#     140         model = self.hypermodel.build(trial.hyperparameters)
# --> 141         return model.fit(*fit_args, **fit_kwargs)
#     142
#     143     def run_trial(self, trial, *fit_args, **fit_kwargs):
#
# ~\anaconda3\envs\notebook1\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~\anaconda3\envs\notebook1\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1135           epoch_logs.update(val_logs)
#    1136
# -> 1137         callbacks.on_epoch_end(epoch, epoch_logs)
#    1138         training_logs = epoch_logs
#    1139         if self.stop_training:
#
# ~\anaconda3\envs\notebook1\lib\site-packages\tensorflow\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     410     for callback in self.callbacks:
#     411       if getattr(callback, '_supports_tf_logs', False):
# --> 412         callback.on_epoch_end(epoch, logs)
#     413       else:
#     414         if numpy_logs is None:  # Only convert once.
#
# ~\anaconda3\envs\notebook1\lib\site-packages\tensorflow\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#    1247     # pylint: disable=protected-access
#    1248     if self.save_freq == 'epoch':
# -> 1249       self._save_model(epoch=epoch, logs=logs)
#    1250
#    1251   def _should_save_on_batch(self, batch):
#
# ~\anaconda3\envs\notebook1\lib\site-packages\tensorflow\python\keras\callbacks.py in _save_model(self, epoch, logs)
#    1297               if self.save_weights_only:
#    1298                 self.model.save_weights(
# -> 1299                     filepath, overwrite=True, options=self._options)
#    1300               else:
#    1301                 self.model.save(filepath, overwrite=True, options=self._options)
#
# ~\anaconda3\envs\notebook1\lib\site-packages\tensorflow\python\keras\engine\training.py in save_weights(self, filepath, overwrite, save_format, options)
#    2099              'saved.\n\nConsider using a TensorFlow optimizer from `tf.train`.')
#    2100             % (optimizer,))
# -> 2101       self._trackable_saver.save(filepath, session=session, options=options)
#    2102       # Record this checkpoint so it's visible from tf.train.latest_checkpoint.
#    2103       checkpoint_management.update_checkpoint_state_internal(
#
# ~\anaconda3\envs\notebook1\lib\site-packages\tensorflow\python\training\tracking\util.py in save(self, file_prefix, checkpoint_number, session, options)
#    1198     file_io.recursive_create_dir(os.path.dirname(file_prefix))
#    1199     save_path, new_feed_additions = self._save_cached_when_graph_building(
# -> 1200         file_prefix_tensor, object_graph_tensor, options)
#    1201     if new_feed_additions:
#    1202       feed_dict.update(new_feed_additions)
#
# ~\anaconda3\envs\notebook1\lib\site-packages\tensorflow\python\training\tracking\util.py in _save_cached_when_graph_building(self, file_prefix, object_graph_tensor, options)
#    1143         or context.executing_eagerly() or ops.inside_function()):
#    1144       saver = functional_saver.MultiDeviceSaver(named_saveable_objects)
# -> 1145       save_op = saver.save(file_prefix, options=options)
#    1146       with ops.device("/cpu:0"):
#    1147         with ops.control_dependencies([save_op]):
#
# ~\anaconda3\envs\notebook1\lib\site-packages\tensorflow\python\training\saving\functional_saver.py in save(self, file_prefix, options)
#     293       tf_function_save()
#     294     else:
# --> 295       return save_fn()
#     296
#     297   def restore(self, file_prefix, options=None):
#
# ~\anaconda3\envs\notebook1\lib\site-packages\tensorflow\python\training\saving\functional_saver.py in save_fn()
#     267           # initial read operations should be placed on the SaveableObject's
#     268           # device.
# --> 269           sharded_saves.append(saver.save(shard_prefix, options))
#     270
#     271       with ops.control_dependencies(sharded_saves):
#
# ~\anaconda3\envs\notebook1\lib\site-packages\tensorflow\python\training\saving\functional_saver.py in save(self, file_prefix, options)
#      76     save_device = options.experimental_io_device or "cpu:0"
#      77     with ops.device(save_device):
# ---> 78       return io_ops.save_v2(file_prefix, tensor_names, tensor_slices, tensors)
#      79
#      80   def restore(self, file_prefix, options=None):
#
# ~\anaconda3\envs\notebook1\lib\site-packages\tensorflow\python\ops\gen_io_ops.py in save_v2(prefix, tensor_names, shape_and_slices, tensors, name)
#    1729       return save_v2_eager_fallback(
#    1730           prefix, tensor_names, shape_and_slices, tensors, name=name,
# -> 1731           ctx=_ctx)
#    1732     except _core._SymbolicException:
#    1733       pass  # Add nodes to the TensorFlow graph.
#
# ~\anaconda3\envs\notebook1\lib\site-packages\tensorflow\python\ops\gen_io_ops.py in save_v2_eager_fallback(prefix, tensor_names, shape_and_slices, tensors, name, ctx)
#    1749   _attrs = ("dtypes", _attr_dtypes)
#    1750   _result = _execute.execute(b"SaveV2", 0, inputs=_inputs_flat, attrs=_attrs,
# -> 1751                              ctx=ctx, name=name)
#    1752   _result = None
#    1753   return _result
#
# ~\anaconda3\envs\notebook1\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# NotFoundError: Failed to create a NewWriteableFile: my_dir\lrcn_tuning\trial_f16d84b5542a97c6c6458e1305bacb35\checkpoints\epoch_0\checkpoint_temp_bac9874d08724626881d59c63684c1fe/part-00000-of-00001.data-00000-of-00001.tempstate16069666868349196590 : The system cannot find the path specified.
# ; No such process [Op:SaveV2]

# %% [markdown]
# # Save Model

# %%
# Save your Model.
model.save("Suspicious_Human_Activity_Detection_LRCN_Model_20240603.h5")

# %% [markdown]
# # Plot Loss and Accuracy Graphs while Training

# %%
def plot_metric(model_training_history, metric_name_1, metric_name_2, plot_name):
    '''
    This function will plot the metrics passed to it in a graph.
    Args:
        model_training_history: A history object containing a record of training and validation 
                                loss values and metrics values at successive epochs
        metric_name_1:          The name of the first metric that needs to be plotted in the graph.
        metric_name_2:          The name of the second metric that needs to be plotted in the graph.
        plot_name:              The title of the graph.
    '''
    
    # Get metric values using metric names as identifiers.
    metric_value_1 = model_training_history.history[metric_name_1]
    metric_value_2 = model_training_history.history[metric_name_2]
    
    # Construct a range object which will be used as x-axis (horizontal plane) of the graph.
    epochs = range(len(metric_value_1))
 
    # Plot the Graph.
    plt.plot(epochs, metric_value_1, 'blue', label = metric_name_1)
    plt.plot(epochs, metric_value_2, 'red', label = metric_name_2)
 
    # Add title to the plot.
    plt.title(str(plot_name))
 
    # Add legend to the plot.
    plt.legend()

# %%
plot_metric(model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# %%
plot_metric(model_training_history, 'accuracy', 'val_accuracy', 'Total Accuracy vs Total Validation Accuracy')

# %% [markdown]
# # Accuracy on Test Dataset

# %%
# Calculate Accuracy On Test Dataset
acc = 0
for i in range(len(features_test)):
  predicted_label = np.argmax(model.predict(np.expand_dims(features_test[i],axis =0))[0])
  actual_label = np.argmax(labels_test[i])
  if predicted_label == actual_label:
      acc += 1
acc = (acc * 100)/len(labels_test)
print("Accuracy =",acc)
# Out:
# Accuracy = 86.36363636363636
